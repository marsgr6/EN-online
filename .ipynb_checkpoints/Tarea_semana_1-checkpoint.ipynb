# %% [markdown]
# ### Tarea semana 1: Análisis descriptivo:
#
# **Problema:**
#
# - Análsis de usabilidad de un sistema informático.
# - Contiene variables de uso del sistema: **Time**, y la escala dada por el usuario: **SUS**.
# - Variables demográficas del usuario, Género (**Gender**), Edad (**Age**), entre otras.
#
# **Archivo:**
#   - UX_data.csv
#
# **Variables:**
#
# - SUS (System Usability Scale): Escala de Usabilidad del Sistema.
#   - Un valor entre 0 y 100, dado por el usuario al evaluar un sistema informático.
#   - Ver: https://www.usability.gov/how-to-and-tools/methods/system-usability-scale.html
#
# - Time: Tiempo en que el usuario realizó la prueba del sistema.
#
# - Gender: M (Male, masculino), F (Female, Femenino).
#
# - Age: twenty (veinte añeros), thirty (treinta añeros), forty (cuarenta añeros).
#
# ### Análisis a realizar:
#
#
# A partir de los datos **UX_data.csv** realice un análisis descriptivo de:
#
#
# 1. Variable numéricas
#
# |       |     SUS |     Time |
# |:------|--------:|---------:|
# | count | 30      |  30      |
# | mean  | 76.0833 | 157.5    |
# | std   | 14.617  |  22.3994 |
# | min   | 40      | 112.7    |
# | 25%   | 68.125  | 140.025  |
# | 50%   | 78.75   | 159.7    |
# | 75%   | 87.5    | 177.05   |
# | max   | 95      | 188.3    |
#
# 2. Variables categóricas
#
# |          |   ID |
# |:---------|-----:|
# | employee |   15 |
# | student  |   15 |
#
# |    |   Gender |
# |:---|---------:|
# | M  |       20 |
# | F  |       10 |
#
# |        |   Age |
# |:-------|------:|
# | twenty |    17 |
# | thirty |     7 |
# | forty  |     6 |
#
# 3. Descripción de variables numéricas agrupadas por **"Gender"**:
#
# |        |           |        F |        M |
# |:--------|:----------|---------:|---------:|
# | **SUS** | count  |  10      |  20      |
# |  | mean   |  74      |  77.125  |
# |  | std   |  17.3285 |  13.4329 |
# |  | min    |  40      |  42.5    |
# |  | 25%    |  66.25   |  69.375  |
# |  | 50%    |  77.5    |  80      |
# |  | 75%    |  87.5    |  87.5    |
# |  | max   |  92.5    |  95      |
# | **Time** | count |  10      |  20      |
# |  | mean  | 172.19   | 150.155  |
# |  | std   |  15.6563 |  21.8936 |
# |  |min   | 144      | 112.7    |
# |  |25%   | 165.975  | 135.6    |
# |  |50%   | 175.5    | 148.65   |
# |  |75%   | 184.75   | 167.3    |
# |  |max   | 188.3    | 185.3    |
#
# 4. Descripción de variables numéricas agrupadas por **"Age"**:
#
#
# |         |          |   twenty |   thirty |     forty |
# |:----------|:--------|---------:|---------:|----------:|
# | **SUS** | count  |  17      |   7      |   6       |
# |  | mean   |  78.0882 |  74.6429 |  72.0833  |
# |  | std    |  15.8983 |  12.5357 |  14.3542  |
# |  | min    |  40      |  57.5    |  52.5     |
# |  | 25%    |  75      |  66.25   |  63.125   |
# |  | 50%    |  80      |  75      |  71.25    |
# |  | 75%    |  87.5    |  83.75   |  85       |
# |  | max    |  95      |  90      |  87.5     |
# | **Time** | count |  17      |   7      |   6       |
# |  | mean  | 146.835  | 166.214  | 177.55    |
# |  | std   |  20.2663 |  22.1184 |   5.76637 |
# |  | min   | 112.7    | 128.3    | 171       |
# |  | 25%   | 135.7    | 154.65   | 173.65    |
# |  | 50%   | 148      | 176.3    | 176       |
# |  | 75%   | 157.7    | 181.8    | 182.325   |
# |  | max   | 188.3    | 186      | 185       |
#
# A partir del análsis descriptivo agrupado que ha realizado, construya los siguientes gráficos:
#
# 1. Diagrama de cajas **Gender vs SUS**:
#
# ![](https://raw.githubusercontent.com/marsgr6/r-scripts/master/imgs/Gender_vs_SUS.png)
#
# 2. Diagrama de cajas **Gender vs Time**:
#
# ![](https://raw.githubusercontent.com/marsgr6/r-scripts/master/imgs/Gender_vs_Time.png)
#
# 3. Diagrama de cajas **Age vs SUS**:
#
# ![](https://raw.githubusercontent.com/marsgr6/r-scripts/master/imgs/Age_vs_SUS.png)
#
# 4. Diagrama de cajas **Age vs Time**:
#
# ![](https://raw.githubusercontent.com/marsgr6/r-scripts/master/imgs/Age_vs_Time.png)
#
# 5. Diagrama de dispersión **SUS vs Time** agrupados por **Gender**:
#
# ![](https://raw.githubusercontent.com/marsgr6/r-scripts/master/imgs/SUS_vs_Time_by_Gender.png)
